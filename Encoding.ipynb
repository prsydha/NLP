# %%
import pandas as pd

# %%
data = {
    'ID': [1,2,3,4],
    'Name': ['Ram', 'Hari', 'Shyam', 'Gita'],
    'Location': ['KTM', 'PKR', 'KTM', 'BRH'],
    'Salary': [20000, 30000, 40000, 50000]
}
df = pd.DataFrame(data)
df.head()
# Out:
#    ID   Name Location  Salary
# 0   1    Ram      KTM   20000
# 1   2   Hari      PKR   30000
# 2   3  Shyam      KTM   40000
# 3   4   Gita      BRH   50000

# %%
# Label Encoding

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Location'] = le.fit_transform(df['Location'])
df.head()
# Out:
#    ID   Name  Location  Salary
# 0   1    Ram         1   20000
# 1   2   Hari         2   30000
# 2   3  Shyam         1   40000
# 3   4   Gita         0   50000

# %%
# One Hot Encoding
df = pd.get_dummies(df, columns=['Location'])
df
# Out:
#    ID   Name  Salary  Location_0  Location_1  Location_2
# 0   1    Ram   20000       False        True       False
# 1   2   Hari   30000       False       False        True
# 2   3  Shyam   40000       False        True       False
# 3   4   Gita   50000        True       False       False
